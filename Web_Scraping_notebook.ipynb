# %% [markdown]
# # Abstract:
#
# #### In this notebook, we are going to extract San Francisco Boutiques information from yelp to further analyze them in our NLP project:
#
# **step1:**  define a function to iterate over all the search result pages and extract all the boutique names and their information.
#
# **step2:**  define a function to return list of reviews with date and rating for a boutique across all of its review pages.
#
# **step3:**  define a function to combine previous steps, iterate over all the result pages and extract all the boutique names, their info and reviews.

# %% [markdown]
# # Objectives:
#
# ## At the end of this notebook we will have two separate csv files:
#
# ### 1. sf_wclothing_boutiques_info.csv
#
# a file with all san francisco women`s clothing boutique names and information including contact_numbers, addresses, URL_pages, price_range and average_ratings
#
# ### 2. sf_wclothing_boutiques_review.csv
#
# a file with all san francisco women`s clothing boutique names, number_reviews, reviews, each review dates and ratings.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob
import pickle

#import bs4 as bs or:
from bs4 import BeautifulSoup
#BeautifulSoup is a Python library for pulling data out of HTML and XML files

import re
import requests
import urllib.request as url
#rllib.request is a Python module for fetching URLs (Uniform Resource Locators).It offers a simple
#interface, in the form of the urlopen function.

from time import sleep
#Need to use a delay between page scrapes in order to limit getting blocked by Yelp

# %% [markdown]
# # step 1:

# %% [markdown]
# #### 1-1. Set main and secondary attributes and class names to each of required features:

# %%
# for all the boutiques in yelp search result:
main_attributes_class="lemon--div__373c0__1mboc mainAttributes__373c0__1r0QA arrange-unit__373c0__o3tjT arrange-unit-fill__373c0__3Sfw1 border-color--default__373c0__3-ifU"
# including:
business_name_class="lemon--div__373c0__1mboc businessName__373c0__1fTgn display--inline-block__373c0__1ZKqC border-color--default__373c0__3-ifU"
rating_class="lemon--span__373c0__3997G display--inline__373c0__3JqBP border-color--default__373c0__3-ifU"
price_range_class="lemon--span__373c0__3997G text__373c0__2Kxyz priceRange__373c0__2DY87 text-color--black-extra-light__373c0__2OyzO text-align--left__373c0__2XGa- text-bullet--after__373c0__3fS1Z"
review_count_class="lemon--span__373c0__3997G text__373c0__2Kxyz reviewCount__373c0__2r4xT text-color--black-extra-light__373c0__2OyzO text-align--left__373c0__2XGa-"

secondary_attributes_class="lemon--div__373c0__1mboc secondaryAttributes__373c0__7bA0w arrange-unit__373c0__o3tjT border-color--default__373c0__3-ifU"
# inclufing:
business_phonenumber_class="lemon--div__373c0__1mboc display--inline-block__373c0__1ZKqC border-color--default__373c0__3-ifU"
business_address_class="lemon--span__373c0__3997G raw__373c0__3rcx7"

# %% [markdown]
# #### 1-2. Define a function to iterate over all the result pages and extract all the boutique names and their information:

# %%
#find_all returns a ResultSet object which you can iterate over using a for loop
def retrieve_boutique_info(num_stores):
    boutique_name=[]
    rating=[]
    number_review=[]
    price_range=[]
    url_address=[]
    phone_number=[]
    address=[]

    #total num_stores in all pages = 240
    for i in range(0, num_stores, 10):
        
        # 1.to track the process, print("search_pages:",i)
        #print(i)
        
        # 2.to iterate over all pages and stores find a url pattern for all search pages:
        url="https://www.yelp.com/search?find_desc=Clothing%20Boutiques&find_loc=San%20Francisco%2C%20CA&ns=1&cflt=womenscloth&start={}".format(i)
        
        # 3.Make a get request to retrieve each page
        html_page = requests.get(url)
        
        # 4.Pass the page contents to beautiful soup for parsing
        soup = BeautifulSoup(html_page.content, 'html.parser')
        
        # 5.find all the div classes/secondary_attributes which refers to all the stores listed on the search result page and set them to mains and secondary_attributes 
        mains=soup.find_all("div",{"class":main_attributes_class})
        secondaries=soup.find_all("div",{"class":secondary_attributes_class})
        
        for main in mains:
            try:
                boutique_name.append(main.find("a").text)
            except:
                boutique_name.append(None)
            try:
                rating.append(main.find("span",{"class":rating_class}).div.get("aria-label"))
            except:
                rating.append(None)
            try:
                number_review.append(main.find("span",{"class":review_count_class}).text)
            except:
                number_review.append(None)
            try:
                price_range.append(main.find("span",{"class":price_range_class}).get_text())
            except:
                price_range.append(None)
            try:
                base_url="https://www.yelp.com"
                business_name_url=main.find('a').attrs['href']
                url_address.append(base_url+business_name_url)
            except:
                url_address.append(None)
        
        
        for secondary in secondaries:
            try:
                phone_number.append(secondary.find("p").text)
            except:
                phone_number.append(None)
            try:
                address.append(secondary.find("span",{"class":business_address_class}).get_text())
            except:
                address.append(None) 
        
        
        #Random delay between 1 and 4 seconds to prevent getting blocked
        sleep(np.random.randint(1,3))
    
    data={"boutique_name":boutique_name,"rating":rating,"number_reviews":number_review,
          "price_range":price_range,"phone_number":phone_number,"address":address,"url_address":url_address}
    df=pd.DataFrame(data)
    
    return df

# %% [markdown]
# #### 1-3. Save the results into a csv file "sf_wclothing_boutiques_info":

# %%
#create the boutiques_info dataframe including all the info for all the boutiques in yelp search result:
boutiques_info_df = retrieve_boutique_info(num_stores=240)

#check the result for duplicate boutique names and their info:
pd.set_option('display.max_rows', 100)
pd.options.display.max_colwidth = 100
boutiques_info_df.head(50)
# Out:
#                                 boutique_name           rating number_reviews  \
# 0                                    Marzel’s    4 star rating             12
# 1               Kisha Studio Fashion Boutique    5 star rating            120
# 2                            Morning Lavender    4 star rating             28
# 3                                        Onyx  4.5 star rating             17
# 4                                Wild Feather    5 star rating             29
# 5   Asmbly Hall - formerly on Fillmore Street  4.5 star rating             26
# 6                                   Two Birds    4 star rating             24
# 7                               Gravel & Gold  4.5 star rating             32
# 8                            Current Clothing    5 star rating             23
# 9                                      ANOMIE  4.5 star rating             15
# 10                             Siren Boutique    5 star rating             12
# 11                                   Marzel’s    4 star rating             12
# 12                                    Chococo  4.5 star rating             26
# 13                             Siren Boutique  4.5 star rating             15
# 14                             Therapy Stores  4.5 star rating            400
# 15                                  Establish    5 star rating             26
# 16                                  Cary Lane  4.5 star rating             54
# 17                             Modern Citizen    4 star rating             14
# 18                                     Ideele    4 star rating             40
# 19                                   Pavilion    5 star rating             14
# 20                                    Curator  4.5 star rating             15
# 21                                  Cary Lane  4.5 star rating             17
# 22                        Intentionally Blank    5 star rating              1
# 23                                      Tonlé    5 star rating             16
# 24                          California Cowboy    5 star rating             21
# 25                                   Ambiance    4 star rating             92
# 26                                  Hero Shop    5 star rating              6
# 27                                   Ambiance    4 star rating            277
# 28                         Lexington Standard    4 star rating              5
# 29                           The Voyager Shop    4 star rating             31
# 30                                Baseballism    5 star rating              9
# 31                                   Le Point    4 star rating             19
# 32                             ALAYA Boutique    4 star rating             58
# 33                        Intentionally Blank    5 star rating              1
# 34                                      Adapt  4.5 star rating             69
# 35                              Sweet & Spark    5 star rating             10
# 36                                        UKO    4 star rating             34
# 37                              Ruru Boutique    5 star rating              1
# 38                            The Golden Hour    5 star rating             19
# 39                          Carolina Boutique    5 star rating             16
# 40                                  KIM + ONO  4.5 star rating             23
# 41                                   Ceiba SF    4 star rating             79
# 42                               High Society    4 star rating             34
# 43                                Lemon Twist  4.5 star rating             26
# 44                        Intentionally Blank    5 star rating              1
# 45                              Scotch & Soda  3.5 star rating             22
# 46                             San Franpsycho    4 star rating             44
# 47                                 Heidi Says    4 star rating             63
# 48                                Eden & Eden  4.5 star rating             39
# 49                           New York Apparel  4.5 star rating            112
#
#    price_range    phone_number              address  \
# 0          $$$  (925) 433-9163    1220 Oakland Blvd
# 1           $$  (415) 422-0468       210 Clement St
# 2           $$  (650) 797-0686        1846 Union St
# 3           $$  (415) 431-6699    289 Divisadero St
# 4          $$$  (415) 786-2614        597 Haight St
# 5           $$  (415) 801-5862    624 Divisadero St
# 6          $$$  (415) 285-1840       1309 Castro St
# 7          $$$  (415) 552-0112         3266 21st St
# 8           $$  (415) 400-5517        1738 Union St
# 9          $$$  (415) 872-9943        2149 Union St
# 10          $$  (415) 702-6747     244 W Portal Ave
# 11         $$$  (925) 433-9163    1220 Oakland Blvd
# 12          $$  (408) 888-7910       455 Clement St
# 13          $$  (415) 757-0617         551 Hayes St
# 14          $$  (415) 865-0981      545 Valencia St
# 15          $$  (415) 564-5054      3811 Noriega St
# 16          $$  (415) 896-4564         3153 16th St
# 17           $  (415) 796-3807        2078 Union St
# 18          $$  (415) 431-8836       1600 Haight St
# 19         $$$  (415) 896-4114         3187 16th St
# 20         $$$  (415) 872-9189        1173 Valencia
# 21          $$  (415) 592-8731         1262 9th Ave
# 22        None  (415) 964-8436     1360 Valencia St
# 23         $$$  (415) 510-9405        55 Clement St
# 24         $$$  (415) 484-6961         1841 Polk St
# 25          $$  (415) 661-1663        756 Irving St
# 26        None  (415) 829-3129          982 Post St
# 27          $$  (415) 647-5800         3979 24th St
# 28        $$$$  (415) 967-4261         3469 18th St
# 29         $$$  (415) 795-1748      365 Valencia St
# 30          $$  (415) 913-7597           761 3rd St
# 31         $$$  (415) 400-4275      301 Valencia St
# 32          $$  (415) 731-2681         1256 9th Ave
# 33        None  (415) 964-8436     1360 Valencia St
# 34          $$  (415) 571-8897        2801 Judah St
# 35        None  (415) 636-9832     2412 Fillmore St
# 36          $$  (415) 252-7719         350 Hayes St
# 37        None  (415) 751-1983       1748 Haight St
# 38          $$  (415) 742-4266       147 Clement St
# 39         $$$  (415) 381-2554  76 Throckmorton Ave
# 40          $$  (415) 989-8588        729 Grant Ave
# 41         $$$  (415) 437-9598       1364 Haight St
# 42         $$$  (415) 447-0447      1969 B Union St
# 43          $$  (415) 297-2423         3418 25th St
# 44        None  (415) 964-8436     1360 Valencia St
# 45         $$$  (415) 644-8334         59 Grant Ave
# 46          $$  (415) 213-5442         1248 9th Ave
# 47         $$$  (415) 749-0655     2426 Fillmore St
# 48          $$  (415) 983-0490       560 Jackson St
# 49           $  (415) 751-8823       1772 Haight St
#
#                                                                                             url_address
# 0   https://www.yelp.com/adredir?ad_business_id=bDdNGMfzsk1xDA-7MQEyWg&campaign_id=ey-zPs_Gwfv8KxEff...
# 1         https://www.yelp.com/biz/kisha-studio-fashion-boutique-san-francisco-2?osq=Clothing+Boutiques
# 2                      https://www.yelp.com/biz/morning-lavender-san-francisco-2?osq=Clothing+Boutiques
# 3                                  https://www.yelp.com/biz/onyx-san-francisco-3?osq=Clothing+Boutiques
# 4                            https://www.yelp.com/biz/wild-feather-san-francisco?osq=Clothing+Boutiques
# 5   https://www.yelp.com/biz/asmbly-hall-formerly-on-fillmore-street-san-francisco?osq=Clothing+Bout...
# 6                             https://www.yelp.com/biz/two-birds-san-francisco-2?osq=Clothing+Boutiques
# 7                         https://www.yelp.com/biz/gravel-and-gold-san-francisco?osq=Clothing+Boutiques
# 8                        https://www.yelp.com/biz/current-clothing-san-francisco?osq=Clothing+Boutiques
# 9                                  https://www.yelp.com/biz/anomie-san-francisco?osq=Clothing+Boutiques
# 10                       https://www.yelp.com/biz/siren-boutique-san-francisco-4?osq=Clothing+Boutiques
# 11  https://www.yelp.com/adredir?ad_business_id=bDdNGMfzsk1xDA-7MQEyWg&campaign_id=ey-zPs_Gwfv8KxEff...
# 12                              https://www.yelp.com/biz/chococo-san-francisco-6?osq=Clothing+Boutiques
# 13                       https://www.yelp.com/biz/siren-boutique-san-francisco-3?osq=Clothing+Boutiques
# 14                         https://www.yelp.com/biz/therapy-stores-san-francisco?osq=Clothing+Boutiques
# 15                              https://www.yelp.com/biz/establish-san-francisco?osq=Clothing+Boutiques
# 16                            https://www.yelp.com/biz/cary-lane-san-francisco-4?osq=Clothing+Boutiques
# 17                         https://www.yelp.com/biz/modern-citizen-san-francisco?osq=Clothing+Boutiques
# 18                                 https://www.yelp.com/biz/ideele-san-francisco?osq=Clothing+Boutiques
# 19                               https://www.yelp.com/biz/pavilion-san-francisco?osq=Clothing+Boutiques
# 20                                https://www.yelp.com/biz/curator-san-francisco?osq=Clothing+Boutiques
# 21                            https://www.yelp.com/biz/cary-lane-san-francisco-6?osq=Clothing+Boutiques
# 22  https://www.yelp.com/adredir?ad_business_id=43vmshloeCqt3Sc9ySXP8g&campaign_id=Fqp0bHjvWT9HZL2rV...
# 23                           https://www.yelp.com/biz/tonl%C3%A9-san-francisco-4?osq=Clothing+Boutiques
# 24                    https://www.yelp.com/biz/california-cowboy-san-francisco-2?osq=Clothing+Boutiques
# 25                             https://www.yelp.com/biz/ambiance-san-francisco-6?osq=Clothing+Boutiques
# 26                              https://www.yelp.com/biz/hero-shop-san-francisco?osq=Clothing+Boutiques
# 27                             https://www.yelp.com/biz/ambiance-san-francisco-4?osq=Clothing+Boutiques
# 28                     https://www.yelp.com/biz/lexington-standard-san-francisco?osq=Clothing+Boutiques
# 29                       https://www.yelp.com/biz/the-voyager-shop-san-francisco?osq=Clothing+Boutiques
# 30                          https://www.yelp.com/biz/baseballism-san-francisco-3?osq=Clothing+Boutiques
# 31                               https://www.yelp.com/biz/le-point-san-francisco?osq=Clothing+Boutiques
# 32                         https://www.yelp.com/biz/alaya-boutique-san-francisco?osq=Clothing+Boutiques
# 33  https://www.yelp.com/adredir?ad_business_id=43vmshloeCqt3Sc9ySXP8g&campaign_id=Fqp0bHjvWT9HZL2rV...
# 34                                  https://www.yelp.com/biz/adapt-san-francisco?osq=Clothing+Boutiques
# 35                      https://www.yelp.com/biz/sweet-and-spark-san-francisco-3?osq=Clothing+Boutiques
# 36                                    https://www.yelp.com/biz/uko-san-francisco?osq=Clothing+Boutiques
# 37                          https://www.yelp.com/biz/ruru-boutique-san-francisco?osq=Clothing+Boutiques
# 38                      https://www.yelp.com/biz/the-golden-hour-san-francisco-2?osq=Clothing+Boutiques
# 39                        https://www.yelp.com/biz/carolina-boutique-mill-valley?osq=Clothing+Boutiques
# 40                              https://www.yelp.com/biz/kim-ono-san-francisco-2?osq=Clothing+Boutiques
# 41                               https://www.yelp.com/biz/ceiba-sf-san-francisco?osq=Clothing+Boutiques
# 42                           https://www.yelp.com/biz/high-society-san-francisco?osq=Clothing+Boutiques
# 43                          https://www.yelp.com/biz/lemon-twist-san-francisco-2?osq=Clothing+Boutiques
# 44  https://www.yelp.com/adredir?ad_business_id=43vmshloeCqt3Sc9ySXP8g&campaign_id=Fqp0bHjvWT9HZL2rV...
# 45                      https://www.yelp.com/biz/scotch-and-soda-san-francisco-2?osq=Clothing+Boutiques
# 46                       https://www.yelp.com/biz/san-franpsycho-san-francisco-3?osq=Clothing+Boutiques
# 47                             https://www.yelp.com/biz/heidi-says-san-francisco?osq=Clothing+Boutiques
# 48                          https://www.yelp.com/biz/eden-and-eden-san-francisco?osq=Clothing+Boutiques
# 49                       https://www.yelp.com/biz/new-york-apparel-san-francisco?osq=Clothing+Boutiques

# %%
# duplicatedrows = boutiques_info_df[boutiques_info_df.duplicated()]
# print(duplicatedrows)

#drop all rows with duplicte boutique_names which are mostly adds:
boutiques_info_df_dropped = boutiques_info_df.drop_duplicates(subset ="boutique_name", keep = False)#, inplace = True) 

#reset the index after dropping duplicates
boutiques_info_df_dropped_reset = boutiques_info_df.reset_index(drop=True)

boutiques_info_df_dropped_reset.head(50)
# Out:
#                                 boutique_name           rating number_reviews  \
# 0               Kisha Studio Fashion Boutique    5 star rating            120
# 1                            Morning Lavender    4 star rating             28
# 2                                        Onyx  4.5 star rating             17
# 3                                Wild Feather    5 star rating             29
# 4   Asmbly Hall - formerly on Fillmore Street  4.5 star rating             26
# 5                                   Two Birds    4 star rating             24
# 6                               Gravel & Gold  4.5 star rating             32
# 7                            Current Clothing    5 star rating             23
# 8                                      ANOMIE  4.5 star rating             15
# 9                                     Chococo  4.5 star rating             26
# 10                             Therapy Stores  4.5 star rating            400
# 11                                  Establish    5 star rating             26
# 12                             Modern Citizen    4 star rating             14
# 13                                     Ideele    4 star rating             40
# 14                                   Pavilion    5 star rating             14
# 15                                    Curator  4.5 star rating             15
# 16                                      Tonlé    5 star rating             16
# 17                          California Cowboy    5 star rating             21
# 18                                  Hero Shop    5 star rating              6
# 19                         Lexington Standard    4 star rating              5
# 20                           The Voyager Shop    4 star rating             31
# 21                                Baseballism    5 star rating              9
# 22                                   Le Point    4 star rating             19
# 23                             ALAYA Boutique    4 star rating             58
# 24                                      Adapt  4.5 star rating             69
# 25                              Sweet & Spark    5 star rating             10
# 26                                        UKO    4 star rating             34
# 27                              Ruru Boutique    5 star rating              1
# 28                            The Golden Hour    5 star rating             19
# 29                          Carolina Boutique    5 star rating             16
# 30                                  KIM + ONO  4.5 star rating             23
# 31                                   Ceiba SF    4 star rating             79
# 32                               High Society    4 star rating             34
# 33                                Lemon Twist  4.5 star rating             26
# 34                             San Franpsycho    4 star rating             44
# 35                                 Heidi Says    4 star rating             63
# 36                                Eden & Eden  4.5 star rating             39
# 37                           New York Apparel  4.5 star rating            112
# 38                            Maison Margiela  4.5 star rating              8
# 39                                       Lexe    5 star rating              6
# 40                                    AB Fits  4.5 star rating            111
# 41                             The Stylist LA    4 star rating             11
# 42                                       Joie  4.5 star rating             13
# 43                        Isabella’s Boutique             None           None
# 44                                     Azalea    3 star rating            335
# 45                              Dish Clothing    4 star rating             50
# 46                         Asmbly Hall - NoPa    5 star rating              5
# 47                           Beyond the Alley  4.5 star rating              9
# 48                                    Aritzia  3.5 star rating            150
# 49                                     Picnic    4 star rating            117
#
#    price_range    phone_number              address  \
# 0           $$  (415) 422-0468       210 Clement St
# 1           $$  (650) 797-0686        1846 Union St
# 2           $$  (415) 431-6699    289 Divisadero St
# 3          $$$  (415) 786-2614        597 Haight St
# 4           $$  (415) 801-5862    624 Divisadero St
# 5          $$$  (415) 285-1840       1309 Castro St
# 6          $$$  (415) 552-0112         3266 21st St
# 7           $$  (415) 400-5517        1738 Union St
# 8          $$$  (415) 872-9943        2149 Union St
# 9           $$  (408) 888-7910       455 Clement St
# 10          $$  (415) 865-0981      545 Valencia St
# 11          $$  (415) 564-5054      3811 Noriega St
# 12           $  (415) 796-3807        2078 Union St
# 13          $$  (415) 431-8836       1600 Haight St
# 14         $$$  (415) 896-4114         3187 16th St
# 15         $$$  (415) 872-9189        1173 Valencia
# 16         $$$  (415) 510-9405        55 Clement St
# 17         $$$  (415) 484-6961         1841 Polk St
# 18        None  (415) 829-3129          982 Post St
# 19        $$$$  (415) 967-4261         3469 18th St
# 20         $$$  (415) 795-1748      365 Valencia St
# 21          $$  (415) 913-7597           761 3rd St
# 22         $$$  (415) 400-4275      301 Valencia St
# 23          $$  (415) 731-2681         1256 9th Ave
# 24          $$  (415) 571-8897        2801 Judah St
# 25        None  (415) 636-9832     2412 Fillmore St
# 26          $$  (415) 252-7719         350 Hayes St
# 27        None  (415) 751-1983       1748 Haight St
# 28          $$  (415) 742-4266       147 Clement St
# 29         $$$  (415) 381-2554  76 Throckmorton Ave
# 30          $$  (415) 989-8588        729 Grant Ave
# 31         $$$  (415) 437-9598       1364 Haight St
# 32         $$$  (415) 447-0447      1969 B Union St
# 33          $$  (415) 297-2423         3418 25th St
# 34          $$  (415) 213-5442         1248 9th Ave
# 35         $$$  (415) 749-0655     2426 Fillmore St
# 36          $$  (415) 983-0490       560 Jackson St
# 37           $  (415) 751-8823       1772 Haight St
# 38         $$$  (415) 917-2101        134 Maiden Ln
# 39        None  (415) 923-8908         2291 Pine St
# 40         $$$  (415) 982-5726       1519 Grant Ave
# 41          $$  (415) 872-9989        1980 Union St
# 42         $$$  (415) 400-0367     2116 Fillmore St
# 43        None  (415) 424-8401      4380 Mission St
# 44         $$$  (415) 861-9888         411 Hayes St
# 45         $$$  (415) 252-5997         541 Hayes St
# 46        None  (415) 801-5862    624 Divisadero St
# 47          $$  (415) 346-0106     2176 Chestnut St
# 48         $$$  (415) 512-7026        865 Market St
# 49          $$  (415) 346-6556         1808 Polk St
#
#                                                                                               url_address
# 0           https://www.yelp.com/biz/kisha-studio-fashion-boutique-san-francisco-2?osq=Clothing+Boutiques
# 1                        https://www.yelp.com/biz/morning-lavender-san-francisco-2?osq=Clothing+Boutiques
# 2                                    https://www.yelp.com/biz/onyx-san-francisco-3?osq=Clothing+Boutiques
# 3                              https://www.yelp.com/biz/wild-feather-san-francisco?osq=Clothing+Boutiques
# 4   https://www.yelp.com/biz/asmbly-hall-formerly-on-fillmore-street-san-francisco?osq=Clothing+Boutiques
# 5                               https://www.yelp.com/biz/two-birds-san-francisco-2?osq=Clothing+Boutiques
# 6                           https://www.yelp.com/biz/gravel-and-gold-san-francisco?osq=Clothing+Boutiques
# 7                          https://www.yelp.com/biz/current-clothing-san-francisco?osq=Clothing+Boutiques
# 8                                    https://www.yelp.com/biz/anomie-san-francisco?osq=Clothing+Boutiques
# 9                                 https://www.yelp.com/biz/chococo-san-francisco-6?osq=Clothing+Boutiques
# 10                           https://www.yelp.com/biz/therapy-stores-san-francisco?osq=Clothing+Boutiques
# 11                                https://www.yelp.com/biz/establish-san-francisco?osq=Clothing+Boutiques
# 12                           https://www.yelp.com/biz/modern-citizen-san-francisco?osq=Clothing+Boutiques
# 13                                   https://www.yelp.com/biz/ideele-san-francisco?osq=Clothing+Boutiques
# 14                                 https://www.yelp.com/biz/pavilion-san-francisco?osq=Clothing+Boutiques
# 15                                  https://www.yelp.com/biz/curator-san-francisco?osq=Clothing+Boutiques
# 16                             https://www.yelp.com/biz/tonl%C3%A9-san-francisco-4?osq=Clothing+Boutiques
# 17                      https://www.yelp.com/biz/california-cowboy-san-francisco-2?osq=Clothing+Boutiques
# 18                                https://www.yelp.com/biz/hero-shop-san-francisco?osq=Clothing+Boutiques
# 19                       https://www.yelp.com/biz/lexington-standard-san-francisco?osq=Clothing+Boutiques
# 20                         https://www.yelp.com/biz/the-voyager-shop-san-francisco?osq=Clothing+Boutiques
# 21                            https://www.yelp.com/biz/baseballism-san-francisco-3?osq=Clothing+Boutiques
# 22                                 https://www.yelp.com/biz/le-point-san-francisco?osq=Clothing+Boutiques
# 23                           https://www.yelp.com/biz/alaya-boutique-san-francisco?osq=Clothing+Boutiques
# 24                                    https://www.yelp.com/biz/adapt-san-francisco?osq=Clothing+Boutiques
# 25                        https://www.yelp.com/biz/sweet-and-spark-san-francisco-3?osq=Clothing+Boutiques
# 26                                      https://www.yelp.com/biz/uko-san-francisco?osq=Clothing+Boutiques
# 27                            https://www.yelp.com/biz/ruru-boutique-san-francisco?osq=Clothing+Boutiques
# 28                        https://www.yelp.com/biz/the-golden-hour-san-francisco-2?osq=Clothing+Boutiques
# 29                          https://www.yelp.com/biz/carolina-boutique-mill-valley?osq=Clothing+Boutiques
# 30                                https://www.yelp.com/biz/kim-ono-san-francisco-2?osq=Clothing+Boutiques
# 31                                 https://www.yelp.com/biz/ceiba-sf-san-francisco?osq=Clothing+Boutiques
# 32                             https://www.yelp.com/biz/high-society-san-francisco?osq=Clothing+Boutiques
# 33                            https://www.yelp.com/biz/lemon-twist-san-francisco-2?osq=Clothing+Boutiques
# 34                         https://www.yelp.com/biz/san-franpsycho-san-francisco-3?osq=Clothing+Boutiques
# 35                               https://www.yelp.com/biz/heidi-says-san-francisco?osq=Clothing+Boutiques
# 36                            https://www.yelp.com/biz/eden-and-eden-san-francisco?osq=Clothing+Boutiques
# 37                         https://www.yelp.com/biz/new-york-apparel-san-francisco?osq=Clothing+Boutiques
# 38                        https://www.yelp.com/biz/maison-margiela-san-francisco-2?osq=Clothing+Boutiques
# 39                                     https://www.yelp.com/biz/lexe-san-francisco?osq=Clothing+Boutiques
# 40                                https://www.yelp.com/biz/ab-fits-san-francisco-4?osq=Clothing+Boutiques
# 41                           https://www.yelp.com/biz/the-stylist-la-san-francisco?osq=Clothing+Boutiques
# 42                                     https://www.yelp.com/biz/joie-san-francisco?osq=Clothing+Boutiques
# 43                      https://www.yelp.com/biz/isabella-s-boutique-san-francisco?osq=Clothing+Boutiques
# 44                                   https://www.yelp.com/biz/azalea-san-francisco?osq=Clothing+Boutiques
# 45                            https://www.yelp.com/biz/dish-clothing-san-francisco?osq=Clothing+Boutiques
# 46                         https://www.yelp.com/biz/asmbly-hall-nopa-san-francisco?osq=Clothing+Boutiques
# 47                         https://www.yelp.com/biz/beyond-the-alley-san-francisco?osq=Clothing+Boutiques
# 48                                  https://www.yelp.com/biz/aritzia-san-francisco?osq=Clothing+Boutiques
# 49                                   https://www.yelp.com/biz/picnic-san-francisco?osq=Clothing+Boutiques

# %%
#save the dataframe as a csv file:
# boutiques_info_df_dropped_reset.to_csv("sf_wclothing_boutiques_info.csv")

# %%
#save the dataframe as a pickle file for further NLP analysis:
#Write data to file
with open('boutique_info.pickle','wb') as f:
    pickle.dump(boutiques_info_df_dropped_reset,f,pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # step 2:
# #### 2-1. Set main attributes and class names to each of required features for **each boutique** review across all of its review pages:

# %%
# for each boutique in its yelp_url_page:
review_mains_class = "lemon--div__373c0__1mboc arrange-unit__373c0__o3tjT arrange-unit-grid-column--8__373c0__2dUx_ border-color--default__373c0__3-ifU"
# including:
review_reviews_class = "lemon--span__373c0__3997G raw__373c0__3rKqk"
review_dates_class = "lemon--span__373c0__3997G text__373c0__2Kxyz text-color--mid__373c0__jCeOG text-align--left__373c0__2XGa-"
review_stars_class = "lemon--span__373c0__3997G display--inline__373c0__3JqBP border-color--default__373c0__3-ifU"

# %% [markdown]
# #### 2-2. Define a function to iterate over all the review pages of **each boutique** and extract all the information:

# %%
#retrieve reviews, date and rate of reviews for each boutique:
#each page has 20 reviews
def retrieve_reviews_info(boutique_name, boutique_url_address, number_reviews):
    url = boutique_url_address  
    total_reviews=[]
    total_review_dates=[]
    total_review_stars=[]
    for i in range(0, int(number_reviews)//20 + 1):
        url_page = url + "&start={}".format(i*20)
        html_page = requests.get(url_page)
        soup = BeautifulSoup(html_page.content, 'html.parser')
        review_mains = soup.find_all("div",{"class":review_mains_class})
        
        for review_main in review_mains:
            try:
                total_reviews.append(review_main.find("span",{"class":review_reviews_class}).text)
            except:
                total_reviews.append(None)
            try:
                total_review_stars.append(review_main.find("span",{"class":review_stars_class}).div.get("aria-label"))
            except:
                total_review_stars.append(None)
            try:
                total_review_dates.append(review_main.find("span",{"class":review_dates_class}).text)
            except:
                total_review_dates.append(None)
    
    data = {"review":total_reviews,"star_rating":total_review_stars,"date":total_review_dates}
    coulmns = ["review","star_rating","date"]
    review_info = pd.DataFrame(data)
                
    return review_info.dropna(subset = ["star_rating","date","review"], how="any")

# %%
#check the results for one store:
pd.options.display.max_colwidth = 500
boutique_name = 'Onyx'
boutique_url_address ="https://www.yelp.com/biz/onyx-san-francisco-3?osq=Clothing+Boutiques"
number_reviews = 17
#to get the results as a dataframe for all three attributes:
myreviews = retrieve_reviews_info(boutique_name, boutique_url_address, number_reviews)
myreviews
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  review  \
# 1                                                                                                                                                                                                                                                    The most magical store full of so many beautiful things. A ton of my favorite things are from Onyx. I constantly get compliments on the Molly M Designs wallet that I bought there. The owners are also super nice and helpful, it's always a treat to shop there.
# 2   Onyx is literally a gem on Divis!Quite a gem +'s:+ Fetching collection for both women and men! The clothing designs reflect someone who understands style without being terribly trendy. Quality of materials show that consumers don't want something from Forever 21.+ Jewelry counter is a gem in itself. Don't forget to browse. Very interesting designs that are unique and worth a look or try.+ Pleasant assistance and someone who has an eye! Don't have her name, but that day, the woman at Onyx mad...
# 3   Just had the same experience as Jessie described. This place seemed to be a total gem and I was loving everything until realizing the shop owner was blatantly ignoring me and my boyfriend, with only us 2 in the shop. I never write reviews but I could not believe how rude this woman was. We spent a good amount of time browsing. When I finally approached the counter to look at jewelry and pick up a card I'm thinking ok now she'll at least acknowledge me.She finally dares to acknowledge my exis...
# 4                                                                                                                                                                                            Onyx is a beautiful boutique! My wife & love it ! It is filled with art (which rotates), clothing and jewelry. Many of the items are from hard to find designers. The owner, Barb, is just fabulous and friendly (as is her dog, Spike). It's a great addition to the neighborhood! Stop by for unique clothing and gifts.
# 5   A well curated, bright open boutique in the Mission.I wanted to slip into every dress in there! The fabrics are incredible. Some of the softest, lightest, and well made pieces.It is clear every item is picked out for a reason. I was so smitten with each and every cut, pleat, seam and silhouette. They had a particular dress on a mannequin I kept coming back to because I KNEW no matter who put it on it was going to hang beautifully and flatter every curve. I walked back to it about a dozen tim...
# 6                                                                                                                                                                                                                                               I live in the neighborhood and love this boutique as well as the ladies who run it. It has a lovely selection with a great variety of prices and styles.  Quality clothes, shoes, jewelry and a small selection of skincare products. Buy small, buy local!Thanks Onyx!
# 7                                                                                                                                                            Exquisite designers from San Francisco and around the world. The two owners, Shannon and Barb, have an incredible eye for clothing and accessories- love these women! Subtle aroma from a "Bir Sur" scented candle and classic rock on vinyl welcome you at the door. You won't be able to leave without your arms weighted down from new styles and gems!
# 8   From the same owners of Onyx in the Mission - comes a new Onyx location - conveniently located on boutique lined Divisadero.Onyx Boutique is full of well chosen garments and accessories. From hip Obey faux red leather jackets lined with casual grey hoodie material, to plush lined casual jackets that make you yearn to never take them off - it is brimming with stylish finds. The space is big and well laid out and will be perfect for hosting fun events and I'm excited to see what other wonderfu...
# 9                                                                                                                       This boutique is a San Francisco gem. The clothing, shoes and jewelry are super urban chic. The owners really have their fingers on the pulse of cool SF style. It's an art and gift gallery also. I just love what they carry in this crunchy casual spot. Even the wallpaper is cool as are the nice friendly ladies who own it. Def worth a visiting often, they get new goodies constantly.
# 10  This is a great neighborhood boutique. I always find something, I especially love their jewelry. They carry really unique pieces from local/West Coast makers. I like that there is a range of prices in their clothing.  While there are some very pricey things, there are usually things within reach too.  I've also had great success with their sample sales..gotten some absolute steals!While they don't carry a huge selection of shoes, what they do have I really like. I've bought a couple great pa...
# 11                                                                                                                                                                                 Got 5 really well priced cute things, earrings, a scent from Holland for my fiance', a cool necklace, an amazing cashmere sweater, and some cute socks. I basically wanted everything in there! Definitely going back for my winter coat! They have these Canadian jackets that are so solid and cute. Really cool mix of designers.
# 12                                                                           Onyx is a gorgeous little boutique in Dolores Heights/Noe Valley that opened this summer. They carry fabulous clothes, shoes, jewelry, accessories, candles and perfume. Many of their products are locally-sourced or indie labels such as Curator, Modaspia and L'Aromatica. Prices range from affordable to luxury. This boutique is the perfect place to find your next "wow them" outfit or a gift for your most stylish lady friend.
# 13  The Divisadero shop is tucked away in an up and coming neighborhood but is always worth the trip. There are staple pieces like the Prairie Underground line (stretchy pants & dresses or jackets that you can live in) as well as specialty lines like Ace and Jig, Stance socks and Amsterdam's Soda and Scotch. It's a little rock and roll, they carry jewelry made from recycled drum cymbals (!) & cool pieces from Portland's Betsy & Iya too. There are also lots of feminine pieces from local designers...
# 14                                                                                                                                                                                                                                                                                                                                                              Love this place - great style, clothes made locally and in California, and cute puppy running around when I was there.  Bought my summer wardrobe here!
# 15                                                            Happy to have one cute place to buy clothes in the hood.  Selection is suited to my style, layout is airy and chic. Prices range from pricey to reasonable.  One of the owner ladies provides great friendly service, likes to talk about clothes, remembers what I bought last time and makes good suggestions.  The woman working there last time I went in utterly ignored me while she played on her computer, seemed annoyed when I asked for sizes.
# 16                                                                                                                                                                                                              Onyx has amazing jewelry that drew me in the first time I walked by the shop. I have fallen instantly for beautiful earrings, bracelets and necklaces in their store. Recently I found a pair of gorgeous j shoe booties and a soft scarf that is a subtle coral color. A very dangerous place to shop!
# 17                                                                                                                                                                                                                                                                          Like its mission counterpart, this Onyx location is a true gem of a shop.  The collections are unique and feature well known lines as well as smaller ones.  If you're looking for something fabulous, you'll surely find it at this store!
#
#       star_rating        date
# 1   5 star rating    4/2/2020
# 2   4 star rating    1/1/2019
# 3   1 star rating   9/10/2017
# 4   5 star rating    9/3/2018
# 5   5 star rating   7/23/2017
# 6   5 star rating    3/6/2017
# 7   5 star rating    9/5/2018
# 8   4 star rating  11/13/2012
# 9   4 star rating   5/24/2017
# 10  5 star rating   1/25/2016
# 11  5 star rating   10/8/2013
# 12  5 star rating   7/12/2012
# 13  5 star rating   1/25/2016
# 14  5 star rating   7/16/2016
# 15  4 star rating   4/14/2014
# 16  5 star rating   2/10/2014
# 17  5 star rating   10/4/2013
